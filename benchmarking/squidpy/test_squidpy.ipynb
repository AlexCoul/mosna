# %%
# ! pip install squidpy

# %%
import squidpy as sq
import scanpy as sc
# Example of loading a sample dataset
adata = sq.datasets.visium_fluo_adata()
adata = sq.im.ImageContainer(adata.uns['spatial']['V1_Adult_Mouse_Brain']['images']['hires'])
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\tempfile.py:256, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     255 try:
# --> 256     fd = _os.open(file, flags, 0o600)
#     257 except FileExistsError:
#
# PermissionError: [Errno 13] Permission denied: 'c:\\ProgramData\\anaconda3\\Lib\\site-packages\\datashader\\transfer_functions\\__pycache__\\tmpnr96n9pv'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import squidpy as sq
#       2 import scanpy as sc
#       3 # Example of loading a sample dataset
#
# File ~\AppData\Roaming\Python\Python311\site-packages\squidpy\__init__.py:3
#       1 from importlib import metadata
# ----> 3 from squidpy import datasets, gr, im, pl, read, tl
#       5 try:
#       6     md = metadata.metadata(__name__)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\squidpy\gr\__init__.py:3
#       1 """The graph module."""
# ----> 3 from squidpy.gr._build import spatial_neighbors
#       4 from squidpy.gr._ligrec import ligrec
#       5 from squidpy.gr._nhood import centrality_scores, interaction_matrix, nhood_enrichment
#
# File ~\AppData\Roaming\Python\Python311\site-packages\squidpy\gr\_build.py:25
#      23 from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
#      24 from sklearn.neighbors import NearestNeighbors
# ---> 25 from spatialdata import SpatialData
#      27 from squidpy._constants._constants import CoordType, Transform
#      28 from squidpy._constants._pkg_constants import Key
#
# File ~\AppData\Roaming\Python\Python311\site-packages\spatialdata\__init__.py:36
#      34 from spatialdata._core.concatenate import concatenate
#      35 from spatialdata._core.data_extent import get_extent
# ---> 36 from spatialdata._core.operations.aggregate import aggregate
#      37 from spatialdata._core.operations.rasterize import rasterize
#      38 from spatialdata._core.operations.transform import transform
#
# File ~\AppData\Roaming\Python\Python311\site-packages\spatialdata\_core\operations\aggregate.py:18
#      16 from shapely import Point
#      17 from spatial_image import SpatialImage
# ---> 18 from xrspatial import zonal_stats
#      20 from spatialdata._core.operations.transform import transform
#      21 from spatialdata._core.query._utils import circles_to_polygons
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xrspatial\__init__.py:1
# ----> 1 from xrspatial.aspect import aspect  # noqa
#       2 from xrspatial.bump import bump  # noqa
#       3 from xrspatial.classify import binary  # noqa
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xrspatial\aspect.py:10
#       7 import xarray as xr
#       8 from numba import cuda
# ---> 10 from xrspatial.utils import ArrayTypeFunctionMapping, cuda_args, ngjit, not_implemented_func
#      12 # 3rd-party
#      13 try:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xrspatial\utils.py:4
#       1 from math import ceil
#       3 import dask.array as da
# ----> 4 import datashader as ds
#       5 import datashader.transfer_functions as tf
#       6 import numpy as np
#
# File c:\ProgramData\anaconda3\Lib\site-packages\datashader\__init__.py:8
#       5 import param
#       6 __version__ = str(param.version.Version(fpath=__file__, archive_commit="$Format:%h$",reponame="datashader"))
# ----> 8 from .core import Canvas                                 # noqa (API import)
#       9 from .reductions import *                                # noqa (API import)
#      10 from .glyphs import Point                                # noqa (API import)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\datashader\core.py:18
#      16 from .utils import Expr # noqa (API import)
#      17 from .resampling import resample_2d, resample_2d_distributed
# ---> 18 from . import reductions as rd
#      20 try:
#      21     import cudf
#
# File c:\ProgramData\anaconda3\Lib\site-packages\datashader\reductions.py:16
#      13 from numba import cuda as nb_cuda
#      15 try:
# ---> 16     from datashader.transfer_functions._cuda_utils import (
#      17         cuda_atomic_nanmin, cuda_atomic_nanmax, cuda_args, cuda_row_min_in_place,
#      18         cuda_nanmax_n_in_place_4d, cuda_nanmax_n_in_place_3d,
#      19         cuda_nanmin_n_in_place_4d, cuda_nanmin_n_in_place_3d,
#      20         cuda_row_max_n_in_place_4d, cuda_row_max_n_in_place_3d,
#      21         cuda_row_min_n_in_place_4d, cuda_row_min_n_in_place_3d, cuda_shift_and_insert,
#      22     )
#      23 except ImportError:
#      24     (cuda_atomic_nanmin, cuda_atomic_nanmax, cuda_args, cuda_row_min_in_place,
#      25         cuda_nanmax_n_in_place_4d, cuda_nanmax_n_in_place_3d,
#      26         cuda_nanmin_n_in_place_4d, cuda_nanmin_n_in_place_3d,
#      27         cuda_row_max_n_in_place_4d, cuda_row_max_n_in_place_3d,
#      28         cuda_row_min_n_in_place_4d, cuda_row_min_n_in_place_3d, cuda_shift_and_insert,
#      29     ) = None, None, None, None, None, None, None, None, None, None, None, None, None
#
# File c:\ProgramData\anaconda3\Lib\site-packages\datashader\transfer_functions\__init__.py:975
#     971     else:
#     972         return img
# --> 975 @nb.jit(nopython=True, nogil=True, cache=True)
#     976 def _array_density(arr, float_type, px=1):
#     977     """Compute a density heuristic of an array.
#     978
#     979     The density is a number in [0, 1], and indicates the normalized mean number
#     980     of non-empty pixels that have neighbors in the given px radius.
#     981     """
#     982     M, N = arr.shape
#
# File c:\ProgramData\anaconda3\Lib\site-packages\numba\core\decorators.py:234, in _jit.<locals>.wrapper(func)
#     230 disp = dispatcher(py_func=func, locals=locals,
#     231                   targetoptions=targetoptions,
#     232                   **dispatcher_args)
#     233 if cache:
# --> 234     disp.enable_caching()
#     235 if sigs is not None:
#     236     # Register the Dispatcher to the type inference mechanism,
#     237     # even though the decorator hasn't returned yet.
#     238     from numba.core import typeinfer
#
# File c:\ProgramData\anaconda3\Lib\site-packages\numba\core\dispatcher.py:863, in Dispatcher.enable_caching(self)
#     862 def enable_caching(self):
# --> 863     self._cache = FunctionCache(self.py_func)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\numba\core\caching.py:601, in Cache.__init__(self, py_func)
#     599 self._name = repr(py_func)
#     600 self._py_func = py_func
# --> 601 self._impl = self._impl_class(py_func)
#     602 self._cache_path = self._impl.locator.get_cache_path()
#     603 # This may be a bit strict but avoids us maintaining a magic number
#
# File c:\ProgramData\anaconda3\Lib\site-packages\numba\core\caching.py:333, in CacheImpl.__init__(self, py_func)
#     331 source_path = inspect.getfile(py_func)
#     332 for cls in self._locator_classes:
# --> 333     locator = cls.from_function(py_func, source_path)
#     334     if locator is not None:
#     335         break
#
# File c:\ProgramData\anaconda3\Lib\site-packages\numba\core\caching.py:180, in _SourceFileBackedLocatorMixin.from_function(cls, py_func, py_file)
#     178 self = cls(py_func, py_file)
#     179 try:
# --> 180     self.ensure_cache_path()
#     181 except OSError:
#     182     # Cannot ensure the cache directory exists or is writable
#     183     return
#
# File c:\ProgramData\anaconda3\Lib\site-packages\numba\core\caching.py:107, in _CacheLocator.ensure_cache_path(self)
#     105 os.makedirs(path, exist_ok=True)
#     106 # Ensure the directory is writable by trying to write a temporary file
# --> 107 tempfile.TemporaryFile(dir=path).close()
#
# File c:\ProgramData\anaconda3\Lib\tempfile.py:563, in NamedTemporaryFile(mode, buffering, encoding, newline, suffix, prefix, dir, delete, errors)
#     561     return fd
#     562 try:
# --> 563     file = _io.open(dir, mode, buffering=buffering,
#     564                     newline=newline, encoding=encoding, errors=errors,
#     565                     opener=opener)
#     566     try:
#     567         raw = getattr(file, 'buffer', file)
#
# File c:\ProgramData\anaconda3\Lib\tempfile.py:560, in NamedTemporaryFile.<locals>.opener(*args)
#     558 def opener(*args):
#     559     nonlocal name
# --> 560     fd, name = _mkstemp_inner(dir, prefix, suffix, flags, output_type)
#     561     return fd
#
# File c:\ProgramData\anaconda3\Lib\tempfile.py:262, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     258     continue    # try again
#     259 except PermissionError:
#     260     # This exception is thrown when a directory with the chosen name
#     261     # already exists on windows.
# --> 262     if (_os.name == 'nt' and _os.path.isdir(dir) and
#     263         _os.access(dir, _os.W_OK)):
#     264         continue
#     265     else:
#
# File <frozen genericpath>:39, in isdir(s)
#
# KeyboardInterrupt:

# %%
sq.gr.spatial_neighbors(adata)

# %%
sc.tl.leiden(adata, key_added="clusters")  # Perform clustering
sq.pl.spatial_scatter(adata, color="clusters")  # Visualize the clustering

# %%
sq.im.calculate_image_features(adata, features=['texture', 'intensity'])

# %%
sq.pl.spatial_scatter(adata, color=['feature_name'])

# %%
sq.pl.spatial_scatter(adata, color='gene_expression')
